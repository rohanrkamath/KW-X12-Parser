# %%
from kw_x12_edi_parser import full_parse_x837p, casual_parse_x837p

# %%
from pathlib import Path

# %%
# casual parsing example (takes only the most important columns)
# we will be using this parsed DF to show the workflow of write_to_edi_x837p method

# File is in same dir as notebook, or use ../edi_examples/edi_sample_25_claims.txt
df1 = casual_parse_x837p("../edi_examples/edi_sample_25_claims.txt")

edi_path = Path("../edi_examples/edi_sample_25_claims.txt")
original_text = edi_path.read_text(encoding="utf-8")

df1["original_837_edi_test"] = original_text

print(f"Shape: {df1.shape[0]} rows x {df1.shape[1]} cols")
df1.head()
# Out:
# Shape: 5 rows x 12 cols
#            provider_name provider_npi provider_address  \
# 0  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 1  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 2  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 3  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 4  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
#
#   provider_city_state_zip  claim_id total_charge  patient_name  \
# 0               GA, 31401  52772237       790.91    JOHN BROWN
# 1               GA, 31401  52772231       596.20   KAREN DAVIS
# 2               GA, 31401  52772228      1117.95   JAMES JONES
# 3               GA, 31401  52772226      2093.18    MARY BROWN
# 4               GA, 31401  52772224       607.16  DAVID WILSON
#
#            payer_name              diagnosis_codes  service_line_count  \
# 0  DEMO PRIMARY PAYER       Z932|J9601|L97222|R339                   2
# 1  DEMO PRIMARY PAYER           R0902|Z433|S31114D                   2
# 2  DEMO PRIMARY PAYER           I872|L97222|L89151                   4
# 3  DEMO PRIMARY PAYER  K219|S31114D|L89151|S31114D                   4
# 4  DEMO PRIMARY PAYER                    Z933|Z433                   1
#
#                 source_file                              original_837_edi_test
# 0  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 1  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 2  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 3  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 4  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...

# %%
# casual parsing example (takes only the most important columns)

df2 = casual_parse_x837p("../edi_examples/edi_sample_50_claims.txt")
print(f"Shape: {df2.shape[0]} rows x {df2.shape[1]} cols")
df2.head()
# Out:
# Shape: 50 rows x 11 cols
#            provider_name provider_npi provider_address  \
# 0  DEMO DME PROVIDER LLC   1578990689  467 EXAMPLE WAY
# 1  DEMO DME PROVIDER LLC   1578990689  467 EXAMPLE WAY
# 2  DEMO DME PROVIDER LLC   1578990689  467 EXAMPLE WAY
# 3  DEMO DME PROVIDER LLC   1578990689  467 EXAMPLE WAY
# 4  DEMO DME PROVIDER LLC   1578990689  467 EXAMPLE WAY
#
#   provider_city_state_zip  claim_id total_charge     patient_name  \
# 0               GA, 30044  52224943      1551.24  ELIZABETH DAVIS
# 1               GA, 30044  52224942      2454.60      KAREN LOPEZ
# 2               GA, 30044  52224941      1461.07      JAMES SMITH
# 3               GA, 30044  52224940      1384.53  LINDA RODRIGUEZ
# 4               GA, 30044  52224939      1478.55    MICHAEL DAVIS
#
#            payer_name              diagnosis_codes  service_line_count  \
# 0  DEMO PRIMARY PAYER            G4733|Z433|N39498                   4
# 1  DEMO PRIMARY PAYER  R0902|J9601|S31114D|S31114D                   4
# 2  DEMO PRIMARY PAYER                 I872|S31114D                   3
# 3  DEMO PRIMARY PAYER                R32|R339|R339                   3
# 4  DEMO PRIMARY PAYER                 M5432|N39498                   2
#
#                 source_file
# 0  edi_sample_50_claims.txt
# 1  edi_sample_50_claims.txt
# 2  edi_sample_50_claims.txt
# 3  edi_sample_50_claims.txt
# 4  edi_sample_50_claims.txt

# %%
# full parsing example (parse all columns in detail)

df3 = full_parse_x837p("../edi_examples/edi_sample_75_claims.txt")

edi_path = Path("../edi_examples/edi_sample_75_claims.txt")
original_text = edi_path.read_text(encoding="utf-8")

df3["original_837_edi_test"] = original_text

print(f"Shape: {df3.shape[0]} rows x {df3.shape[1]} cols")
df3.head()
# Out:
# Shape: 75 rows x 451 cols
#         claim_id          provider_name provider_npi  \
# 0  52058893-1000  DEMO DME PROVIDER LLC   1503517893
# 1  52058892-1001  DEMO DME PROVIDER LLC   1503517893
# 2  52058891-1002  DEMO DME PROVIDER LLC   1503517893
# 3  52058890-1003  DEMO DME PROVIDER LLC   1503517893
# 4  52058889-1004  DEMO DME PROVIDER LLC   1503517893
#
#   ST_Transaction_Set_Identifier_Code ST_Transaction_Set_Control_Number  \
# 0                                837                              0001
# 1                                837                              0001
# 2                                837                              0001
# 3                                837                              0001
# 4                                837                              0001
#
#    BHT_Date BHT_Time BHT_Reference_Identification  \
# 0  20260218     1441                    100000202
# 1  20260218     1441                    100000202
# 2  20260218     1441                    100000202
# 3  20260218     1441                    100000202
# 4  20260218     1441                    100000202
#
#   CLM_Claim_Submitters_Identifier CLM_Monetary_Amount  ... SVD_5_Amount  \
# 0                   52058893-1000             1789.98  ...        64.53
# 1                   52058892-1001              701.29  ...          NaN
# 2                   52058891-1002             2390.92  ...       509.96
# 3                   52058890-1003             1229.38  ...          NaN
# 4                   52058889-1004             2406.90  ...       582.42
#
#   SVD_5_Composite SVD_5_PayerIdentifier SVD_6_Amount SVD_6_Composite  \
# 0        HC:E0601                 62308          NaN             NaN
# 1             NaN                   NaN          NaN             NaN
# 2        HC:K0004                 95327       186.25        HC:E0630
# 3             NaN                   NaN          NaN             NaN
# 4        HC:E1390                 95327          NaN             NaN
#
#   SVD_6_PayerIdentifier TRANSACTION_ID                 file_name  \
# 0                   NaN      100000202  edi_sample_75_claims.txt
# 1                   NaN      100000202  edi_sample_75_claims.txt
# 2                 95327      100000202  edi_sample_75_claims.txt
# 3                   NaN      100000202  edi_sample_75_claims.txt
# 4                   NaN      100000202  edi_sample_75_claims.txt
#
#                 source_file                              original_837_edi_test
# 0  edi_sample_75_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 1  edi_sample_75_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 2  edi_sample_75_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 3  edi_sample_75_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 4  edi_sample_75_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
#
# [5 rows x 451 columns]

# %%
# test for stitching back claims into EDI format on claims deletion from original EDI file.
# randomly remove 10 rows from the dataframe; this is to simulate claims being held, which in this case is 10, and the rest are set to be released.

import random

rows_to_drop = random.sample(list(df1.index), 10)
df_reduced = df1.drop(rows_to_drop)

print(f"Original: {df1.shape[0]} rows x {df1.shape[1]} cols")
print(f"Reduced:  {df_reduced.shape[0]} rows x {df_reduced.shape[1]} cols")
df_reduced.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       1 # test for stitching back claims into EDI format on claims deletion from original EDI file.
#       2 # randomly remove 10 rows from the dataframe; this is to simulate claims being held, which in this case is 10, and the rest are set to be released.
#       4 import random
# ----> 6 rows_to_drop = random.sample(list(df1.index), 10)
#       7 df_reduced = df1.drop(rows_to_drop)
#       9 print(f"Original: {df1.shape[0]} rows x {df1.shape[1]} cols")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/random.py:434, in Random.sample(self, population, k, counts)
#     432 randbelow = self._randbelow
#     433 if not 0 <= k <= n:
# --> 434     raise ValueError("Sample larger than population or is negative")
#     435 result = [None] * k
#     436 setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
from kw_x12_edi_parser import write_to_edi_x837p

# original EDI text and filename from the DataFrame
original_text = df_reduced["original_837_edi_test"].iloc[0]
original_filename = df_reduced["source_file"].iloc[0]

write_to_edi_x837p(
    df_reduced,
    original_filename,
    original_edi=original_text,
)

# The result is a new EDI file with the same name as the original file, but with the claims removed from the block above.

# %%
# test to see if the resulting EDI file is parsable 

df1 = casual_parse_x837p("edi_sample_25_claims.txt")

edi_path = Path("edi_sample_25_claims.txt")
original_text = edi_path.read_text(encoding="utf-8")

df1["original_837_edi_test"] = original_text

print(f"Shape: {df1.shape[0]} rows x {df1.shape[1]} cols")
df1.head()

# from the result below, we are able to parse the output EDI file from above successfully.
# Out:
# Shape: 5 rows x 12 cols
#            provider_name provider_npi provider_address  \
# 0  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 1  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 2  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 3  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
# 4  DEMO DME PROVIDER LLC   1796233790  381 EXAMPLE WAY
#
#   provider_city_state_zip  claim_id total_charge  patient_name  \
# 0               GA, 31401  52772237       790.91    JOHN BROWN
# 1               GA, 31401  52772231       596.20   KAREN DAVIS
# 2               GA, 31401  52772228      1117.95   JAMES JONES
# 3               GA, 31401  52772226      2093.18    MARY BROWN
# 4               GA, 31401  52772224       607.16  DAVID WILSON
#
#            payer_name              diagnosis_codes  service_line_count  \
# 0  DEMO PRIMARY PAYER       Z932|J9601|L97222|R339                   2
# 1  DEMO PRIMARY PAYER           R0902|Z433|S31114D                   2
# 2  DEMO PRIMARY PAYER           I872|L97222|L89151                   4
# 3  DEMO PRIMARY PAYER  K219|S31114D|L89151|S31114D                   4
# 4  DEMO PRIMARY PAYER                    Z933|Z433                   1
#
#                 source_file                              original_837_edi_test
# 0  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 1  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 2  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 3  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
# 4  edi_sample_25_claims.txt  ISA*00*          *00*          *ZZ*99999DEMO  ...
